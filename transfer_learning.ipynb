# %%
# !python train.py --weights yolov5s.pt --data "C:/Users/jonas/Desktop/HoferThomas/TL_Flug_Landung_big/skijumper.yaml" --epochs 50 --batch -1
# Out:
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      7025023       15.95         0.256         54.85         26.93        (1, 3, 640, 640)                    list
#      7025023       31.91         0.428         20.94         19.28        (2, 3, 640, 640)                    list
#      7025023       63.82         0.828          23.6          26.6        (4, 3, 640, 640)                    list
#      7025023       127.6         1.657         33.58         31.58        (8, 3, 640, 640)                    list
#      7025023       255.3         3.209         49.87         56.18       (16, 3, 640, 640)                    list
# ...
